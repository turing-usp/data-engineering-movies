# %%
from extract import ExtractDataTMDB

# %% [markdown]
# ## Extração e tratamento dos dados na API

# %% [markdown]
# - Primeiro, é preciso definir os campos a mais que são desejados par ao dataset de filmes
# - O campo de `imdb_id` é importante para buscar no crawler
# - `revenue` e `budget` são campos que abrem espaço para diversas análises
# - Para obter as `collections` e `productions` relacionadas a cada filme, foi usada uma função que obtém apenas o nome de cada um desses elementos listados dentro do filme

# %%
movie_details = [
    'imdb_id', 
    'status', 
    'revenue', 
    'budget',
    {'fieldName': 'belongs_to_collection', 'finalName': 'collection', 'func': lambda x: x['name'] if x else None},
    {'fieldName': 'production_companies', 'finalName': 'productions', 'func': lambda prod: [x['name'] for x in prod]}
]
serie_details = detail_fields = [
    'in_production',
    'episode_run_time',
    'number_of_seasons',
    'number_of_seasons',
    'number_of_episodes',
    {'fieldName' : 'networks', 'finalName': 'networks', 'func': (lambda networks: [n['name'] for n in networks])}
]

# %%
extract_movies = ExtractDataTMDB(movie_details)
extract_tv = ExtractDataTMDB(serie_details, 'tv')

# %% [markdown]
# - Extranindo dados da rota trending para filmes: o _placeholder_ `:t` é substituído pelo tipo de mídia da extração (nesse caso, `movie`)

# %%
trending_movies = extract_movies.get_route('/trending/:t/week',initial_page=1, final_page=2)

# %%
trending_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 505642 to 49046
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           40 non-null     object
#  1   original_title  40 non-null     object
#  2   overview        40 non-null     object
#  3   poster_path     40 non-null     object
#  4   media_type      40 non-null     object
#  5   popularity      40 non-null     float64
#  6   release_date    40 non-null     datetime64[ns]
#  7   vote_average    40 non-null     float64
#  8   vote_count      40 non-null     int64
#  9   imdb_id         40 non-null     object
#  10  status          40 non-null     object
#  11  revenue         40 non-null     int64
#  12  budget          40 non-null     int64
#  13  collection      12 non-null     object
#  14  productions     40 non-null     object
#  15  genres          40 non-null     object
#  16  release_year    40 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(10)
# memory usage: 5.6+ KB

# %%
trending_movies.head()
# Out:
#                                      title                  original_title  \
# id
# 505642  Pantera Negra: Wakanda para Sempre  Black Panther: Wakanda Forever
# 615777                           Babilônia                         Babylon
# 536554                               M3GAN                           M3GAN
# 646389                       Alerta Máximo                           Plane
# 76600            Avatar: O Caminho da Água        Avatar: The Way of Water
#
#                                                  overview  \
# id
# 505642  A rainha Ramonda, Shuri, M'Baku, Okoye e as po...
# 615777  Durante a era de ouro de Hollywood, em Los Ang...
# 536554  Uma brilhante roboticista de uma empresa de br...
# 646389  O piloto Brodie Torrance salva seus passageiro...
# 76600   12 anos depois de explorar Pandora e se juntar...
#
#                                               poster_path media_type  \
# id
# 505642  https://image.tmdb.org/t/p/w220_and_h330_face/...      movie
# 615777  https://image.tmdb.org/t/p/w220_and_h330_face/...      movie
# 536554  https://image.tmdb.org/t/p/w220_and_h330_face/...      movie
# 646389  https://image.tmdb.org/t/p/w220_and_h330_face/...      movie
# 76600   https://image.tmdb.org/t/p/w220_and_h330_face/...      movie
#
#         popularity release_date  vote_average  vote_count     imdb_id  \
# id
# 505642    9051.476   2022-11-09         7.487        2675   tt9114286
# 615777     877.163   2022-12-22         7.694         839  tt10640346
# 536554    2438.483   2022-12-28         7.577        1369   tt8760708
# 646389     830.679   2023-01-13         6.769         175   tt5884796
# 76600     1635.498   2022-12-14         7.744        5084   tt1630029
#
#           status     revenue     budget              collection  \
# id
# 505642  Released   835000000  250000000  Pantera Negra: Coleção
# 615777  Released    42110960   78000000                    None
# 536554  Released   158000000   12000000        M3GAN Collection
# 646389  Released    29000000   25000000                    None
# 76600   Released  2176000000  460000000         Avatar: Coleção
#
#                                               productions  \
# id
# 505642                                   [Marvel Studios]
# 615777  [Paramount, Marc Platt Productions, Material P...
# 536554  [Universal Pictures, Blumhouse Productions, At...
# 646389  [Di Bonaventura Pictures, MadRiver Pictures, R...
# 76600    [Lightstorm Entertainment, 20th Century Studios]
#
#                                       genres  release_year
# id
# 505642   [Ação, Aventura, Ficção científica]          2022
# 615777                      [Drama, Comédia]          2022
# 536554  [Ficção científica, Terror, Comédia]          2022
# 646389            [Ação, Aventura, Thriller]          2023
# 76600    [Ficção científica, Aventura, Ação]          2022

# %% [markdown]
# - Extraindo dados da rota trending para séries

# %%
trending_tv = extract_tv.get_route('/trending/:t/week', initial_page=1, final_page=4)

# %%
trending_tv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 100088 to 112581
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               80 non-null     object
#  1   original_title      80 non-null     object
#  2   overview            80 non-null     object
#  3   poster_path         80 non-null     object
#  4   media_type          80 non-null     object
#  5   popularity          80 non-null     float64
#  6   release_date        80 non-null     datetime64[ns]
#  7   vote_average        80 non-null     float64
#  8   vote_count          80 non-null     int64
#  9   origin_country      80 non-null     object
#  10  in_production       80 non-null     bool
#  11  episode_run_time    80 non-null     object
#  12  number_of_seasons   80 non-null     int64
#  13  number_of_episodes  80 non-null     int64
#  14  networks            80 non-null     object
#  15  genres              80 non-null     object
#  16  release_year        80 non-null     int64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(4), object(9)
# memory usage: 10.7+ KB

# %%
trending_tv.head()
# Out:
#                  title  original_title  \
# id
# 100088  The Last of Us  The Last of Us
# 210757    The Knockout              狂飙
# 204541      Three Body              三体
# 213241  Lockwood & Co.  Lockwood & Co.
# 119051        Wandinha       Wednesday
#
#                                                  overview  \
# id
# 100088  Situado duas décadas após a implosão de nossa ...
# 210757  Depois de 20 anos de dedicação incansável, jov...
# 204541  Um especialista em nanomateriais vê uma mister...
# 213241  Em um mundo infestado de fantasmas, três adole...
# 119051  Inteligente, sarcástica e apática, Wandinha Ad...
#
#                                               poster_path media_type  \
# id
# 100088  https://image.tmdb.org/t/p/w220_and_h330_face/...         tv
# 210757  https://image.tmdb.org/t/p/w220_and_h330_face/...         tv
# 204541  https://image.tmdb.org/t/p/w220_and_h330_face/...         tv
# 213241  https://image.tmdb.org/t/p/w220_and_h330_face/...         tv
# 119051  https://image.tmdb.org/t/p/w220_and_h330_face/...         tv
#
#         popularity release_date  vote_average  vote_count origin_country  \
# id
# 100088    6329.856   2023-01-15         8.837        1480           [US]
# 210757     233.976   2023-01-14         8.167          30           [CN]
# 204541    1766.251   2023-01-15         8.380          71           [CN]
# 213241      64.177   2023-01-27         7.966          73           [GB]
# 119051    1291.168   2022-11-23         8.660        6260           [US]
#
#         in_production episode_run_time  number_of_seasons  number_of_episodes  \
# id
# 100088           True             [60]                  1                   9
# 210757          False             [45]                  1                  39
# 204541           True             [43]                  1                  30
# 213241           True             [43]                  1                   8
# 119051           True               []                  2                   8
#
#                        networks  \
# id
# 100088                    [HBO]
# 210757          [CCTV-8, iQiyi]
# 204541  [CCTV-8, Tencent Video]
# 213241                [Netflix]
# 119051                [Netflix]
#
#                                                   genres  release_year
# id
# 100088                           [Drama, Ação, Aventura]          2023
# 210757          [Crime, Mistério, Drama, Ação, Aventura]          2023
# 204541              [Drama, Ficção científica, Fantasia]          2023
# 213241                     [Ficção científica, Fantasia]          2023
# 119051  [Ficção científica, Fantasia, Mistério, Comédia]          2022
